# %%
# Trained in kaggle notebooks with chessdataset as input
# !pip install ultralytics --no-deps
# !pip install numpy==1.26.4 --force-reinstall

from ultralytics import YOLO
import torch, numpy

data_path = "/kaggle/input/chessdataset/data.yaml"


# !yolo detect train model=yolov8n.pt data=/kaggle/input/chessdataset/data.yaml epochs=9 imgsz=640 name=train3
